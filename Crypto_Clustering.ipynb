# %%
# Import required libraries and dependencies
import pandas as pd
import hvplot.pandas
from sklearn.cluster import KMeans
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler

# %%
# Load the data into a Pandas DataFrame
df_market_data = pd.read_csv(
    "Resources/crypto_market_data.csv",
    index_col="coin_id")

# Display sample data
df_market_data.head(10)
# Out:
#                  price_change_percentage_24h  price_change_percentage_7d  \
# coin_id
# bitcoin                              1.08388                     7.60278
# ethereum                             0.22392                    10.38134
# tether                              -0.21173                     0.04935
# ripple                              -0.37819                    -0.60926
# bitcoin-cash                         2.90585                    17.09717
# binancecoin                          2.10423                    12.85511
# chainlink                           -0.23935                    20.69459
# cardano                              0.00322                    13.99302
# litecoin                            -0.06341                     6.60221
# bitcoin-cash-sv                      0.92530                     3.29641
#
#                  price_change_percentage_14d  price_change_percentage_30d  \
# coin_id
# ...

# %%
# Generate summary statistics
df_market_data.describe()
# Out:
#        price_change_percentage_24h  price_change_percentage_7d  \
# count                    41.000000                   41.000000
# mean                     -0.269686                    4.497147
# std                       2.694793                    6.375218
# min                     -13.527860                   -6.094560
# 25%                      -0.608970                    0.047260
# 50%                      -0.063410                    3.296410
# 75%                       0.612090                    7.602780
# max                       4.840330                   20.694590
#
#        price_change_percentage_14d  price_change_percentage_30d  \
# count                    41.000000                    41.000000
# mean                      0.185787                     1.545693
# std                       8.376939                    26.344218
# min                     -18.158900                   -34.705480
# 25%                      -5.026620                   -10.438470
# ...

# %%
# Plot your data to see what's in your DataFrame
df_market_data.hvplot.line(
    width=800,
    height=400,
    rot=90
)
# Out:
# :NdOverlay   [Variable]
#    :Curve   [coin_id]   (value)

# %% [markdown]
# ---

# %% [markdown]
# ### Prepare the Data

# %%
# Use the `StandardScaler()` module from scikit-learn to normalize the data from the CSV file
market_data_scaled = StandardScaler().fit_transform(df_market_data)
market_data_scaled[0:5]
# Out:
# array([[ 0.50852937,  0.49319307,  0.77220043,  0.23545963, -0.0674951 ,
#         -0.35595348, -0.25163688],
#        [ 0.18544589,  0.93444504,  0.55869212, -0.05434093, -0.27348273,
#         -0.11575947, -0.19935211],
#        [ 0.02177396, -0.70633685, -0.02168042, -0.06103015,  0.00800452,
#         -0.55024692, -0.28206051],
#        [-0.04076438, -0.81092807,  0.24945797, -0.05038797, -0.37316402,
#         -0.45825882, -0.29554614],
#        [ 1.19303608,  2.00095907,  1.76061001,  0.54584206, -0.29120287,
#         -0.49984776, -0.27031695]])

# %%
# Create a DataFrame with the scaled data
df_market_data_scaled = pd.DataFrame(
    market_data_scaled,
    columns=df_market_data.columns
)




# Copy the crypto names from the original data to this dataframe
# df_market_data.index.to_frame()


df_market_data_scaled['coin_id'] = df_market_data.index

# # Set the coinid column as index
df_market_data_scaled.set_index("coin_id", inplace=True)


# # Display sample data
df_market_data_scaled.head(10)

# df_market_data.index
# df_market_data_scaled
# Out:
#                  price_change_percentage_24h  price_change_percentage_7d  \
# coin_id
# bitcoin                             0.508529                    0.493193
# ethereum                            0.185446                    0.934445
# tether                              0.021774                   -0.706337
# ripple                             -0.040764                   -0.810928
# bitcoin-cash                        1.193036                    2.000959
# binancecoin                         0.891871                    1.327295
# chainlink                           0.011397                    2.572251
# cardano                             0.102530                    1.508001
# litecoin                            0.077497                    0.334297
# bitcoin-cash-sv                     0.448952                   -0.190684
#
#                  price_change_percentage_14d  price_change_percentage_30d  \
# coin_id
# ...

# %% [markdown]
# ---

# %% [markdown]
# ### Find the Best Value for k Using the Original Data.

# %%
# Create a list with the number of k-values from 1 to 11
inertia = []
k = list(range(1, 11))

# %%
# Create an empty list to store the inertia values


# Create a for loop to compute the inertia with each possible value of k
# Inside the loop:
# 1. Create a KMeans model using the loop counter for the n_clusters
# 2. Fit the model to the data using `df_market_data_scaled`
# 3. Append the model.inertia_ to the inertia list
for i in k:
    km = KMeans(n_clusters=i, random_state=0)
    km.fit(df_market_data_scaled)
    inertia.append(km.inertia_)
# Out:
# d:\Programs\Anaconda\envs\dev\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# d:\Programs\Anaconda\envs\dev\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# d:\Programs\Anaconda\envs\dev\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# d:\Programs\Anaconda\envs\dev\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# ...

# %%
# Create a dictionary with the data to plot the Elbow curve
elbow_data = {"k": k, "inertia": inertia}


# Create a DataFrame with the data to plot the Elbow curve
df_elbow = pd.DataFrame(elbow_data)
df_elbow.head(10)
# Out:
#     k     inertia
# 0   1  287.000000
# 1   2  195.820218
# 2   3  123.190482
# 3   4   79.022435
# 4   5   65.302379
# 5   6   52.888518
# 6   7   43.914690
# 7   8   37.517032
# 8   9   32.485241
# 9  10   28.222899

# %%
# Plot a line chart with all the inertia values computed with 
# the different values of k to visually identify the optimal value for k.
df_elbow.hvplot.line(
    x="k",
    y="inertia",
    title="Elbow Curve",
    xticks=k
)
# Out:
# :Curve   [k]   (inertia)

# %% [markdown]
# #### Answer the following question:
#
# **Question:** What is the best value for `k`?
#
# **Answer:**  It is 4

# %% [markdown]
# ---

# %% [markdown]
# ### Cluster Cryptocurrencies with K-means Using the Original Data

# %%
# Initialise the K-Means model using the best value for k
model = KMeans(n_clusters=4, random_state=0)

# %%
# Fit the K-Means model using the scaled data
model.fit(df_market_data_scaled)
# Out:
# d:\Programs\Anaconda\envs\dev\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# KMeans(n_clusters=4, random_state=0)

# %%
# Predict the clusters to group the cryptocurrencies using the scaled data
predictions = model.predict(df_market_data_scaled)


# Print the resulting array of cluster values.
predictions
# Out:
# array([0, 0, 3, 3, 0, 0, 0, 0, 0, 3, 3, 3, 3, 0, 3, 0, 3, 3, 0, 3, 3, 0,
#        3, 3, 3, 3, 3, 3, 0, 3, 3, 3, 1, 0, 3, 3, 2, 3, 3, 3, 3])

# %%
# Create a copy of the DataFrame
clustered_df = df_market_data_scaled.copy()

# %%
# Add a new column to the DataFrame with the predicted clusters
clustered_df["class"] = predictions


# Display sample data
# clustered_df[clustered_df['class'] == 2]
clustered_df['class'].value_counts()
# Out:
# class
# 3    26
# 0    13
# 1     1
# 2     1
# Name: count, dtype: int64

# %%
# Create a scatter plot using hvPlot by setting 
# `x="price_change_percentage_24h"` and `y="price_change_percentage_7d"`. 
# Colour the graph points with the labels found using K-Means and 
# add the crypto name in the `hover_cols` parameter to identify 
# the cryptocurrency represented by each data point.
clustered_df.hvplot.scatter(
    x="price_change_percentage_24h",
    y="price_change_percentage_7d",
    by="class",
    hover_cols=["coin_id"]
)
# Out:
# :NdOverlay   [class]
#    :Scatter   [price_change_percentage_24h]   (price_change_percentage_7d,coin_id)

# %% [markdown]
# ---

# %% [markdown]
# ### Optimise Clusters with Principal Component Analysis.

# %%
# Create a PCA model instance and set `n_components=3`.
pca = PCA(n_components=3)

# %%
# Use the PCA model with `fit_transform` to reduce to 
# three principal components.
crypto_pca = pca.fit_transform(df_market_data_scaled)

# View the first five rows of the DataFrame. 
crypto_pca.shape
# Out:
# (41, 3)

# %%
# Retrieve the explained variance to determine how much information 
# can be attributed to each principal component.
pca.explained_variance_ratio_.sum()
# Out:
# 0.8950316570309841

# %% [markdown]
# #### Answer the following question:
#
# **Question:** What is the total explained variance of the three principal components?
#
# **Answer:** It is the sum of the array pca.explained_variance_ratio (89.5%)

# %%
# Create a new DataFrame with the PCA data.
df_crypto_pca = pd.DataFrame(
    data=crypto_pca,
    columns=["PC_1", "PC_2", "PC_3"],
    index=df_market_data_scaled.index
)

df_crypto_pca.head(10)
# Creating a DataFrame with the PCA data

# Copy the crypto names from the original data


# Set the coinid column as index


# Display sample data
# Out:
#                      PC_1      PC_2      PC_3
# coin_id
# bitcoin         -0.600667  0.842760  0.461595
# ethereum        -0.458261  0.458466  0.952877
# tether          -0.433070 -0.168126 -0.641752
# ripple          -0.471835 -0.222660 -0.479053
# bitcoin-cash    -1.157800  2.041209  1.859715
# binancecoin     -0.516534  1.388377  0.804071
# chainlink       -0.450711  0.517699  2.846143
# cardano         -0.345600  0.729439  1.478013
# litecoin        -0.649468  0.432165  0.600303
# bitcoin-cash-sv -0.759014 -0.201200 -0.217653

# %% [markdown]
# ---

# %% [markdown]
# ### Find the Best Value for k Using the PCA Data

# %%
# Create a list with the number of k-values from 1 to 11
inertia_pca = []
k_pca = list(range(1, 11))

# %%
# Create an empty list to store the inertia values


# Create a for loop to compute the inertia with each possible value of k
# Inside the loop:
# 1. Create a KMeans model using the loop counter for the n_clusters
# 2. Fit the model to the data using `df_market_data_pca`
# 3. Append the model.inertia_ to the inertia list
for i in k_pca:
    km = KMeans(n_clusters=i, random_state=0, n_init='auto')
    km.fit(df_crypto_pca)
    inertia_pca.append(km.inertia_)

# %%
# Create a dictionary with the data to plot the Elbow curve
elbow_data_pca = {"k": k_pca, "inertia": inertia_pca}

# Create a DataFrame with the data to plot the Elbow curve
df_elbow_pca = pd.DataFrame(elbow_data_pca)

# %%
# Plot a line chart with all the inertia values computed with 
# the different values of k to visually identify the optimal value for k.
df_elbow_pca.hvplot.line(
    x="k",
    y="inertia",
    title="Elbow Curve",
    xticks=k_pca
)
# Out:
# :Curve   [k]   (inertia)

# %% [markdown]
# #### Answer the following questions:
#
# * **Question:** What is the best value for `k` when using the PCA data?
#
#   * **Answer:** It is 4.
#
#
# * **Question:** Does it differ from the best k value found using the original data?
#
#   * **Answer:** No, it is the same.

# %% [markdown]
# ### Cluster Cryptocurrencies with K-means Using the PCA Data

# %%
# Initialise the K-Means model using the best value for k
model = KMeans(n_clusters=4, random_state=0, n_init='auto')

# %%
# Fit the K-Means model using the PCA data
model.fit(df_crypto_pca)
# Out:
# KMeans(n_clusters=4, n_init='auto', random_state=0)

# %%
# Predict the clusters to group the cryptocurrencies using the PCA data
predictions_pca = model.predict(df_crypto_pca)

# Print the resulting array of cluster values.
predictions_pca
# Out:
# array([0, 0, 3, 3, 0, 0, 0, 0, 0, 3, 3, 3, 3, 0, 3, 0, 3, 3, 0, 3, 3, 0,
#        3, 3, 3, 3, 3, 3, 0, 3, 3, 3, 1, 0, 3, 3, 2, 3, 3, 3, 3])

# %%
# Create a copy of the DataFrame with the PCA data
clustered_pca_df = df_crypto_pca.copy()


# Add a new column to the DataFrame with the predicted clusters
clustered_pca_df["class"] = predictions_pca


# Display sample data
clustered_pca_df.head(10)
# Out:
#                      PC_1      PC_2      PC_3  class
# coin_id
# bitcoin         -0.600667  0.842760  0.461595      0
# ethereum        -0.458261  0.458466  0.952877      0
# tether          -0.433070 -0.168126 -0.641752      3
# ripple          -0.471835 -0.222660 -0.479053      3
# bitcoin-cash    -1.157800  2.041209  1.859715      0
# binancecoin     -0.516534  1.388377  0.804071      0
# chainlink       -0.450711  0.517699  2.846143      0
# cardano         -0.345600  0.729439  1.478013      0
# litecoin        -0.649468  0.432165  0.600303      0
# bitcoin-cash-sv -0.759014 -0.201200 -0.217653      3

# %%
# Create a scatter plot using hvPlot by setting 
# `x="PC1"` and `y="PC2"`. 
# Colour the graph points with the labels found using K-Means and 
# add the crypto name in the `hover_cols` parameter to identify 
# the cryptocurrency represented by each data point.
clustered_pca_df.hvplot.scatter(
    x="PC_1",
    y="PC_2",
    by="class",
    hover_cols=["coin_id"]
)
# Out:
# :NdOverlay   [class]
#    :Scatter   [PC_1]   (PC_2,coin_id)

# %% [markdown]
# ### Visualise and Compare the Results
#
# In this section, you will visually analyse the cluster analysis results by contrasting the outcome with and without using the optimisation techniques.

# %%
# Composite plot to contrast the Elbow curves
# df_elbow.hvplot.line(
#     x="k",
#     y="inertia",
#     title="Elbow Curve",
#     xticks=k,
#     legend = True
# ) * df_elbow_pca.hvplot.line(
#     x="k",
#     y="inertia",
#     title="Elbow Curve PCA",
#     xticks=k,
#     legend = True
# )
df_elbow['source']= 'Original'	
df_elbow_pca['source']= 'PCA'
df_combined = pd.concat([df_elbow, df_elbow_pca])
df_combined.hvplot.line(
    x="k",
    y="inertia",
    title="Elbow Curve",
    xticks=k,
    by = 'source'
)
# Out:
# :NdOverlay   [source]
#    :Curve   [k]   (inertia)

# %%
# Composite plot to contrast the clusters
plot1 = clustered_df.hvplot.scatter(
    x="price_change_percentage_24h",
    y="price_change_percentage_7d",
    by="class",
    hover_cols=["coin_id"],
    legend = True,
    title = 'Original'
) 
plot2 = clustered_pca_df.hvplot.scatter(
    x="PC_1",
    y="PC_2",
    by="class",
    hover_cols=["coin_id"],
    legend = True,
    title = 'PCA'
)
plot1 + plot2
# Out:
# d:\Programs\Anaconda\envs\dev\Lib\site-packages\holoviews\plotting\bokeh\plot.py:987: UserWarning: found multiple competing values for 'toolbar.active_drag' property; using the latest value
#   layout_plot = gridplot(
# d:\Programs\Anaconda\envs\dev\Lib\site-packages\holoviews\plotting\bokeh\plot.py:987: UserWarning: found multiple competing values for 'toolbar.active_scroll' property; using the latest value
#   layout_plot = gridplot(
# :Layout
#    .NdOverlay.I  :NdOverlay   [class]
#       :Scatter   [price_change_percentage_24h]   (price_change_percentage_7d,coin_id)
#    .NdOverlay.II :NdOverlay   [class]
#       :Scatter   [PC_1]   (PC_2,coin_id)

# %% [markdown]
# #### Answer the following question:
#
#   * **Question:** After visually analysing the cluster analysis results, what is the impact of using fewer features to cluster the data using K-Means?
#
#   * **Answer:** Using feature features result in the points being more closely clustered together.

# %%
# Composite plot to contrast the clusters for each pair of principal components
plot1 = clustered_pca_df.hvplot.scatter(
    x="PC_1",
    y="PC_2",
    by="class",
    hover_cols=["coin_id"],
    legend = True,
    title = 'PCA_12'
)
plot2 = clustered_pca_df.hvplot.scatter(
    x="PC_1",
    y="PC_3",
    by="class",
    hover_cols=["coin_id"],
    legend = True,
    title = 'PCA_13'
)
plot3 = clustered_pca_df.hvplot.scatter(
    x="PC_2",
    y="PC_3",
    by="class",
    hover_cols=["coin_id"],
    legend = True,
    title = 'PCA_23'
)
plot1 + plot2 + plot3
# Out:
# d:\Programs\Anaconda\envs\dev\Lib\site-packages\holoviews\plotting\bokeh\plot.py:987: UserWarning: found multiple competing values for 'toolbar.active_drag' property; using the latest value
#   layout_plot = gridplot(
# d:\Programs\Anaconda\envs\dev\Lib\site-packages\holoviews\plotting\bokeh\plot.py:987: UserWarning: found multiple competing values for 'toolbar.active_scroll' property; using the latest value
#   layout_plot = gridplot(
# :Layout
#    .NdOverlay.I   :NdOverlay   [class]
#       :Scatter   [PC_1]   (PC_2,coin_id)
#    .NdOverlay.II  :NdOverlay   [class]
#       :Scatter   [PC_1]   (PC_3,coin_id)
#    .NdOverlay.III :NdOverlay   [class]
#       :Scatter   [PC_2]   (PC_3,coin_id)

# %%
# combining the points into one plot
# showing colors by class
clustered_df.hvplot.scatter(
    x="price_change_percentage_24h",
    y="price_change_percentage_7d",
    by="class",
    hover_cols=["coin_id"],
    legend = True,
    title = 'Composite Original vs PCA'
) * clustered_pca_df.hvplot.scatter(
    x="PC_1",
    y="PC_2",
    by="class",
    hover_cols=["coin_id"],
    legend = True,
    title = 'PCA'
)
# Out:
# :Overlay
#    .NdOverlay.I  :NdOverlay   [class]
#       :Scatter   [price_change_percentage_24h]   (price_change_percentage_7d,coin_id)
#    .NdOverlay.II :NdOverlay   [class]
#       :Scatter   [PC_1]   (PC_2,coin_id)

# %%
# combining the points into one df by extracting the relevant columns
clustered_df['source'] = 'Original'
clustered_pca_df['source'] = 'PCA'
clustered_pca_df 
clustered_df2 = clustered_df[["price_change_percentage_24h","price_change_percentage_7d",'source', 'class']].rename(columns={"price_change_percentage_24h": "PC_1", "price_change_percentage_7d": "PC_2"})
clustered_combined = pd.concat([clustered_df2, clustered_pca_df[["PC_1", "PC_2", "source", "class"]]], axis=0)
# clustered_combined
clustered_combined
clustered_combined['source_class']  = clustered_combined['source'] + '_' + clustered_combined['class'].astype(str)

# %%
# showing colors by sourec_class using viridis colormap
clustered_combined
clustered_combined.hvplot.scatter(
    x="PC_1",
    y="PC_2",
    by="source_class",
    hover_cols=["coin_id"],
    legend = True,
    title = 'Composite Original vs PCA',
    cmap = 'RdBu'
    # color = 'source'
)
# Out:
# :NdOverlay   [source_class]
#    :Scatter   [PC_1]   (PC_2,coin_id)

# %%
# showing colors by sourec_class using RdBu colormap
clustered_combined.hvplot.scatter(
    x="PC_1",
    y="PC_2",
    by="source_class",
    hover_cols=["coin_id"],
    legend = True,
    title = 'Composite Original vs PCA',
    cmap = 'viridis'
    # color = 'source'
)
# Out:
# :NdOverlay   [source_class]
#    :Scatter   [PC_1]   (PC_2,coin_id)
